# %%
#import
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Buscando o menor size das imagem**

# %%
path = "dataset_sidi.csv"
df = pd.read_csv(path, sep='\t')
df
# Out:
#                   image_name       NEG       NEU       POS  \
# 0       768097808037605376-1  0.919993  0.055681  0.024326
# 1       768097833215938560-1  0.864726  0.058440  0.076834
# 2       768097929659817984-1  0.907574  0.061396  0.031029
# 3       768097929659817984-2  0.907574  0.061396  0.031029
# 4       768097929659817984-3  0.907574  0.061396  0.031029
# ...                      ...       ...       ...       ...
# 470581  804618699315539969-1  0.453963  0.387611  0.158427
# 470582  804618854466981888-1  0.651498  0.208690  0.139812
# 470583  804619265546387457-1  0.473848  0.382078  0.144074
# 470584  804619315861393408-1  0.402850  0.337901  0.259249
# 470585  804619403946000384-1  0.694700  0.182601  0.122700
#
#                                                      text sent_text  \
# 0       RT @hoseokahhh: "who is this song forwhat do i...       NEG
# 1       RT @ARapperSaid_: “I ain’t come over here for ...       NEG
# 2       RT @blackedfriction: i hate telling people i l...       NEG
# 3       RT @blackedfriction: i hate telling people i l...       NEG
# 4       RT @blackedfriction: i hate telling people i l...       NEG
# ...                                                   ...       ...
# 470581  Chances not to loose&gt;&gt;&gt;https://t.co/j...       NEG
# 470582  Don't hear this much  RT @phillynewsnow: Lyft ...       NEG
# 470583  Security agencies threaten to assassinate me –...       NEG
# 470584  Kill my trusted old assistant? Why, no. I'm go...       NEG
# 470585  It’s cold outside: Winter-Essentials. - https:...       NEG
#
#         sent_image                           image_path
# 0                0  data/76809/768097808037605376-1.jpg
# 1                0  data/76809/768097833215938560-1.jpg
# 2                0  data/76809/768097929659817984-1.jpg
# 3                0  data/76809/768097929659817984-2.jpg
# 4                0  data/76809/768097929659817984-3.jpg
# ...            ...                                  ...
# 470581           0  data/80461/804618699315539969-1.jpg
# 470582           0  data/80461/804618854466981888-1.jpg
# 470583           0  data/80461/804619265546387457-1.jpg
# 470584           0  data/80461/804619315861393408-1.jpg
# 470585           0  data/80461/804619403946000384-1.jpg
#
# [470586 rows x 8 columns]

# %%
path_image = "C:/Users/bhla/Residencia/Sidi/Analise de Sentimento/Datasets/b-t4sa_imgs/"
height = 10000000
width = 100000000
imagem_menor = ""

for i in df["image_path"]:

    img = cv2.imread(path_image+i)
    if (img.shape[0]<height and img.shape[1] <width):
        height = img.shape[0]
        width = img.shape[1]
        imagem_menor  = i

        
height,width
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11724/4143073909.py in <module>
#       6 for i in df["image_path"]:
#       7
# ----> 8     img = cv2.imread(path_image+i)
#       9     plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB));
#      10     if (img.shape[0]<height and img.shape[1] <width):
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000001F97B6D6310> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3\envs\DataScience\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3\envs\DataScience\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\anaconda3\envs\DataScience\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\envs\DataScience\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3\envs\DataScience\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\envs\DataScience\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2288                 )
#    2289                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2290                     self.figure.draw(renderer)
#    2291
#    2292             if bbox_inches:
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2801
#    2802             self.patch.draw(renderer)
# -> 2803             mimage._draw_list_compositing_images(
#    2804                 renderer, self, artists, self.suppressComposite)
#    2805
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer)
#    3080             renderer.stop_rasterizing()
#    3081
# -> 3082         mimage._draw_list_compositing_images(
#    3083             renderer, self, artists, self.figure.suppressComposite)
#    3084
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib\image.py in draw(self, renderer, *args, **kwargs)
#     644                 renderer.draw_image(gc, l, b, im, trans)
#     645         else:
# --> 646             im, l, b, trans = self.make_image(
#     647                 renderer, renderer.get_image_magnification())
#     648             if im is not None:
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib\image.py in make_image(self, renderer, magnification, unsampled)
#     954         clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     955                 else self.figure.bbox)
# --> 956         return self._make_image(self._A, bbox, transformed_bbox, clip,
#     957                                 magnification, unsampled=unsampled)
#     958
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib\image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     556                     self, A[..., 3], out_shape, t, alpha=alpha)
#     557                 output = _resample(  # resample rgb channels
# --> 558                     self, _rgb_to_rgba(A[..., :3]), out_shape, t, alpha=alpha)
#     559                 output[..., 3] = output_alpha  # recombine rgb and alpha
#     560
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib\image.py in _rgb_to_rgba(A)
#     206     """
#     207     rgba = np.zeros((A.shape[0], A.shape[1], 4), dtype=A.dtype)
# --> 208     rgba[:, :, :3] = A
#     209     if rgba.dtype == np.uint8:
#     210         rgba[:, :, 3] = 255
#
# KeyboardInterrupt:

# %%
img = cv2.imread(path_image+imagem_menor)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB));
# Out:
# (55, 60)
